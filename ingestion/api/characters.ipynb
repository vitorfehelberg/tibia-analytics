# %%
# %run ../../config/api_client

# %%
#asyncio.run(get_world_characters(['Calmera']))             # Estimated execution time: 00:00:45 
#asyncio.run(get_world_characters(['Antica', 'Luminera']))  # Estimated execution time: 00:01:30
asyncio.run(get_world_characters())                         # Estimated execution time: 01:05:00
