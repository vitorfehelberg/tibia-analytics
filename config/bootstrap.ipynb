-- %%
CREATE CATALOG IF NOT EXISTS tibia_analytics
COMMENT 'Catalog for analyzing player activity and community health in Tibia';

-- %%
USE CATALOG tibia_analytics;

-- %%
CREATE SCHEMA IF NOT EXISTS utils
COMMENT 'Utility schema for storing reference and derived tables.';
CREATE SCHEMA IF NOT EXISTS bronze
COMMENT 'Raw, ingested data as received from sources.';
CREATE SCHEMA IF NOT EXISTS silver
COMMENT 'Cleaned and transformed data ready for analysis.';
CREATE SCHEMA IF NOT EXISTS gold
COMMENT 'Aggregated, business-level metrics and datasets for reporting.';

-- %%
USE SCHEMA bronze;

-- %%
CREATE VOLUME IF NOT EXISTS raw
COMMENT 'Storage for raw ingested data files.';
